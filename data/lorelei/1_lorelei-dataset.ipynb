# %%
# !unzip /content/drive/MyDrive/lorelei_vietnamese_repr_lang_pack_LDC2020T17.zip -d /content/drive/MyDrive
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/lorelei_vietnamese_repr_lang_pack/data/translation/found/vie/psm/VIE_WL_003023_20121103_G0023F184.psm.xml
#   inflating: /content/drive/MyDrive/lorelei_vietnamese_repr_lang_pack/data/translation/found/vie/psm/VIE_NW_003023_20120609_G0023F1C0.psm.xml
#   inflating: /content/drive/MyDrive/lorelei_vietnamese_repr_lang_pack/data/translation/found/vie/psm/VIE_WL_003023_20140710_G0023F2PC.psm.xml
#   inflating: /content/drive/MyDrive/lorelei_vietnamese_repr_lang_pack/data/translation/found/vie/psm/VIE_WL_003023_20151214_G0023F2DA.psm.xml
#   inflating: /content/drive/MyDrive/lorelei_vietnamese_repr_lang_pack/data/translation/found/vie/psm/VIE_WL_003023_20110921_G0023F1KX.psm.xml
#   inflating: /content/drive/MyDrive/lorelei_vietnamese_repr_lang_pack/data/translation/found/vie/psm/VIE_NW_003023_20111027_G0023F1JB.psm.xml
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import glob
print(len(glob.glob("/content/lorelei_vietnamese_repr_lang_pack/data/annotation/sem_annotation/*")))
print(glob.glob("/content/lorelei_vietnamese_repr_lang_pack/data/annotation/sem_annotation/*"))
# Out:
# 0
# []

# %%
sem_laf_list = glob.glob("/content/drive/MyDrive/lorelei_vietnamese_repr_lang_pack/data/annotation/sem_annotation/*")
ltf_file = glob.glob("/content/drive/MyDrive/lorelei_vietnamese_repr_lang_pack/data/monolingual_text/*")

# %%
ltf_file
# Out:
# ['/content/drive/MyDrive/lorelei_vietnamese_repr_lang_pack/data/monolingual_text/zipped']

# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse("/content/lorelei_vietnamese_repr_lang_pack/data/annotation/sem_annotation/VIE_DF_000746_20150426_G0022DCHX.laf.xml")
root = tree.getroot() 
all_lst = []
size = root.findall('EXTENT')
# height = int(size.find('height').text)
# width = float(size.find('width').text)

# %%
for child in root:
     print(child.tag, child.attrib)
     for child2 in child:
       print(child2.tag, child2.attrib)
       for child3 in child2:
         print(child2.tag, child2.attrib)
# Out:
# DOC {'id': 'VIE_DF_000746_20150426_G0022DCHX', 'lang': 'vie'}
# ANNOTATION {'id': 'VIE_DF_000746_20150426_G0022DCHX-pred-5', 'task': 'SSA'}
# ANNOTATION {'id': 'VIE_DF_000746_20150426_G0022DCHX-pred-5', 'task': 'SSA'}
# ANNOTATION {'id': 'VIE_DF_000746_20150426_G0022DCHX-pred-5', 'task': 'SSA'}
# ANNOTATION {'id': 'VIE_DF_000746_20150426_G0022DCHX-pred-5', 'task': 'SSA'}
# ANNOTATION {'id': 'VIE_DF_000746_20150426_G0022DCHX-arg-5-10', 'task': 'SSA'}
# ANNOTATION {'id': 'VIE_DF_000746_20150426_G0022DCHX-arg-5-10', 'task': 'SSA'}
# ANNOTATION {'id': 'VIE_DF_000746_20150426_G0022DCHX-arg-5-10', 'task': 'SSA'}
# ANNOTATION {'id': 'VIE_DF_000746_20150426_G0022DCHX-arg-5-10', 'task': 'SSA'}
# ANNOTATION {'id': 'VIE_DF_000746_20150426_G0022DCHX-arg-5-10', 'task': 'SSA'}
# ANNOTATION {'id': 'VIE_DF_000746_20150426_G0022DCHX-pred-14', 'task': 'SSA'}
# ANNOTATION {'id': 'VIE_DF_000746_20150426_G0022DCHX-pred-14', 'task': 'SSA'}
# ...
